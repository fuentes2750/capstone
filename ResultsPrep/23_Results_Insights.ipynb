# %% [markdown]
# This notebook will take the results of the best model and the results of the popular recommendation engine and prepare/format them so that they are ready for dashboard creation.

# %%
# Loading basic needed libraries
import pandas as pd
import numpy as np
import gc

# Loading libraries for S3 bucket connection
import boto3
import io
from io import StringIO,BytesIO, TextIOWrapper
import gzip

client = boto3.client('s3') 
resource = boto3.resource('s3')

# %%
# Reading CNN best model
CNN_recs = pd.read_csv('s3://myaws-capstone-bucket/data/modeling/output/CNN_param1.csv')
CNN_recs.head()
# Out:
#    userID  Category_Rank  catID  \
# 0       1              0    789
# 1       1              1    669
# 2       1              2    726
# 3       1              5    715
# 4       1              3    606
#
#                                             category          category_id  \
# 0                  2232732108613223108_sport.trainer  2232732108613223108
# 1       2232732093077520756_construction.tools.light  2232732093077520756
# 2  2232732101063475749_appliances.environment.vacuum  2232732101063475749
# 3   2232732099754852875_appliances.personal.massager  2232732099754852875
# 4                  2232732079706079299_sport.bicycle  2232732079706079299
#
#      user_id
# 0  128968633
# 1  128968633
# 2  128968633
# 3  128968633
# 4  128968633

# %%
# Pivoting results so that they are on wanted format
pivot_cNN = (CNN_recs.set_index(['user_id', 'Category_Rank'])['category'].unstack().reset_index().rename_axis(None, axis=1))
pivot_cNN.columns = ['user_id', 'recommendation#1', 'recommendation#2', 'recommendation#3', 'recommendation#4', 'recommendation#5', 'recommendation#6', 'recommendation#7', 'recommendation#8', 'recommendation#9', 'recommendation#10']
pivot_cNN.head()
# Out:
#      user_id                                   recommendation#1  \
# 0  128968633                  2232732108613223108_sport.trainer
# 1  145611266  2053013552259662037_computers.components.power...
# 2  221480173          2232732101407408685_apparel.shoes.slipons
# 3  237973968  2232732091307524418_appliances.kitchen.refrige...
# 4  259560538                2053013556856619499_accessories.bag
#
#                                    recommendation#2  \
# 0      2232732093077520756_construction.tools.light
# 1      2232732093077520756_construction.tools.light
# 2      2232732093077520756_construction.tools.light
# 3      2232732093077520756_construction.tools.light
# 4  2053013566142809077_construction.tools.generator
#
#                                     recommendation#3  \
# 0  2232732101063475749_appliances.environment.vacuum
# 1                  2232732079706079299_sport.bicycle
# 2   2232732099754852875_appliances.personal.massager
# 3  2232732101063475749_appliances.environment.vacuum
# 4       2232732093077520756_construction.tools.light
#
#                                     recommendation#4  \
# 0                  2232732079706079299_sport.bicycle
# 1        2053013557477376525_furniture.bathroom.bath
# 2    2053013554658804075_electronics.audio.headphone
# 3  2232732091718566220_appliances.kitchen.refrige...
# 4     2232732091391410500_appliances.kitchen.blender
#
#                                    recommendation#5  \
# 0            2053013557452210699_electronics.clocks
# 1  2053013566142809077_construction.tools.generator
# 2                 2232732079706079299_sport.bicycle
# 3     2232732092297380188_appliances.kitchen.washer
# 4     2232732092297380188_appliances.kitchen.washer
#
#                                    recommendation#6  \
# 0  2232732099754852875_appliances.personal.massager
# 1    2232732091391410500_appliances.kitchen.blender
# 2            2232732103101907535_electronics.clocks
# 3                 2232732079706079299_sport.bicycle
# 4            2232732115617710964_apparel.shoes.keds
#
#                                     recommendation#7  \
# 0             2232732082063278200_electronics.clocks
# 1  2232732101063475749_appliances.environment.vacuum
# 2  2232732101063475749_appliances.environment.vacuum
# 3   2232732099754852875_appliances.personal.massager
# 4      2232732093857661318_furniture.bedroom.blanket
#
#                                   recommendation#8  \
# 0  2053013554658804075_electronics.audio.headphone
# 1                   2232732105635267203_kids.swing
# 2    2232732092297380188_appliances.kitchen.washer
# 3   2232732091391410500_appliances.kitchen.blender
# 4     2232732105912091273_appliances.kitchen.mixer
#
#                                     recommendation#9  \
# 0    2232732082390433922_electronics.audio.subwoofer
# 1    2053013554658804075_electronics.audio.headphone
# 2  2232732089587859740_appliances.personal.hair_c...
# 3             2053013557452210699_electronics.clocks
# 4    2232732102414041665_computers.components.cooler
#
#                                  recommendation#10
# 0     2232732093345956218_construction.tools.light
# 1     2232732105912091273_appliances.kitchen.mixer
# 2   2053013551882174655_construction.tools.welding
# 3  2053013554658804075_electronics.audio.headphone
# 4      2053013557477376525_furniture.bathroom.bath

# %%
pivot_cNN.nunique()
# Out:
# user_id              535748
# recommendation#1        809
# recommendation#2        616
# recommendation#3        611
# recommendation#4        606
# recommendation#5        617
# recommendation#6        631
# recommendation#7        643
# recommendation#8        643
# recommendation#9        645
# recommendation#10       641
# dtype: int64

# %%
# Saving results of recommendations in S3
pivot_cNN.to_csv('s3://myaws-capstone-bucket/data/cnn_recs_final.csv',index=False)

# %%
# Reading popularity recs model
pop_recs = pd.read_csv('s3://myaws-capstone-bucket/data/modeling/output/popular_recs.csv')
# Dropping duplicates to only keep the top popular recs for each cluster
pop_recs = pop_recs.drop_duplicates(subset=['cluster', 'category', 'purchase_rank'])
pop_recs.head()
# Out:
#      user_id  cluster                                         category  \
# 0  512823699        2       2053013555631882655_electronics.smartphone
# 1  512823699        2     2232732093077520756_construction.tools.light
# 2  512823699        2                2232732079706079299_sport.bicycle
# 3  512823699        2  2053013554658804075_electronics.audio.headphone
# 4  512823699        2                2232732103831716449_apparel.shoes
#
#    purchase_rank
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
# Pivoting popular recs so that they are on the desired format for dashboard
pivot_pop_recs = (pop_recs.set_index(['cluster', 'purchase_rank'])['category'].unstack().reset_index().rename_axis(None, axis=1))
pivot_pop_recs.columns = ['cluster', 'pop_rec#1', 'pop_rec#2', 'pop_rec#3', 'pop_rec#4', 'pop_rec#5', 'pop_rec#6', 'pop_rec#7', 'pop_rec#8', 'pop_rec#9', 'pop_rec#10']
pivot_pop_recs.head(10)
# Out:
#    cluster                                     pop_rec#1  \
# 0        0  2232732093077520756_construction.tools.light
# 1        1    2053013555631882655_electronics.smartphone
# 2        2    2053013555631882655_electronics.smartphone
# 3        3  2232732093077520756_construction.tools.light
# 4        4  2232732093077520756_construction.tools.light
# 5        5  2232732093077520756_construction.tools.light
#
#                                       pop_rec#2  \
# 0    2053013555631882655_electronics.smartphone
# 1  2232732093077520756_construction.tools.light
# 2  2232732093077520756_construction.tools.light
# 3    2053013555631882655_electronics.smartphone
# 4    2053013555631882655_electronics.smartphone
# 5             2232732079706079299_sport.bicycle
#
#                                            pop_rec#3  \
# 0    2053013554658804075_electronics.audio.headphone
# 1      2053013563810775923_appliances.kitchen.washer
# 2                  2232732079706079299_sport.bicycle
# 3                  2232732079706079299_sport.bicycle
# 4                  2232732079706079299_sport.bicycle
# 5  2232732101063475749_appliances.environment.vacuum
#
#                                           pop_rec#4  \
# 0  2232732099754852875_appliances.personal.massager
# 1            2053013558920217191_computers.notebook
# 2   2053013554658804075_electronics.audio.headphone
# 3   2053013554658804075_electronics.audio.headphone
# 4   2053013554658804075_electronics.audio.headphone
# 5        2053013555631882655_electronics.smartphone
#
#                                            pop_rec#5  \
# 0                  2232732079706079299_sport.bicycle
# 1    2053013554658804075_electronics.audio.headphone
# 2                  2232732103831716449_apparel.shoes
# 3   2232732099754852875_appliances.personal.massager
# 4  2232732101063475749_appliances.environment.vacuum
# 5                  2232732103831716449_apparel.shoes
#
#                                            pop_rec#6  \
# 0      2232732092297380188_appliances.kitchen.washer
# 1           2053013554415534427_electronics.video.tv
# 2  2232732101063475749_appliances.environment.vacuum
# 3             2232732103101907535_electronics.clocks
# 4   2232732099754852875_appliances.personal.massager
# 5  2232732089587859740_appliances.personal.hair_c...
#
#                                            pop_rec#7  \
# 0             2232732103101907535_electronics.clocks
# 1  2053013565983425517_appliances.environment.vacuum
# 2  2053013565983425517_appliances.environment.vacuum
# 3      2232732092297380188_appliances.kitchen.washer
# 4           2053013554415534427_electronics.video.tv
# 5     2232732091391410500_appliances.kitchen.blender
#
#                                            pop_rec#8  \
# 0  2232732101063475749_appliances.environment.vacuum
# 1  2053013563911439225_appliances.kitchen.refrige...
# 2     2232732091391410500_appliances.kitchen.blender
# 3           2053013554415534427_electronics.video.tv
# 4      2232732092297380188_appliances.kitchen.washer
# 5       2232732086928670945_electronics.camera.photo
#
#                                            pop_rec#9  \
# 0  2232732091718566220_appliances.kitchen.refrige...
# 1             2053013561579406073_electronics.clocks
# 2          2232732098446229999_apparel.shoes.sandals
# 3  2232732101063475749_appliances.environment.vacuum
# 4      2053013563810775923_appliances.kitchen.washer
# 5    2053013554658804075_electronics.audio.headphone
#
#                                           pop_rec#10
# 0  2053013563835941749_appliances.kitchen.refrige...
# 1             2053013553341792533_electronics.clocks
# 2      2232732102103663163_furniture.bedroom.blanket
# 3  2053013554725912943_appliances.kitchen.coffee_...
# 4             2232732103101907535_electronics.clocks
# 5          2232732098446229999_apparel.shoes.sandals

# %%
# Saving results of popular recommendations in S3
pivot_pop_recs.to_csv('s3://myaws-capstone-bucket/data/pop_recs_final.csv',index=False)
